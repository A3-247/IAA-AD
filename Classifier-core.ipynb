# %%
#load data
import scipy.io as scio
data={ }

# %%
import numpy as np #Import Matrix Processing Library
from numpy import array

# %%
import pandas as pd
df = pd.read_csv("./ADNI_MUL_T1_6_24_2024.csv",encoding="ANSI")
df_array = np.array(df)
df_list = df_array.tolist()

# %%
import pandas as pd
dfA = pd.read_csv("./ADNI_MUL_add_T1_7_28_2024Z.csv",encoding="ANSI")
df_arrayA = np.array(dfA)
df_listA = df_arrayA.tolist()

# %%
tA,tB,tC,tD=0,0,0,0
X_2dA = [[0 for i in range(8)]for j in range(29)]
Y_2dA =[0 for i in range(29)]
X_2dB = [[0 for i in range(8)]for j in range(49)]
Y_2dB =[0 for i in range(49)]
X_2dC = [[0 for i in range(8)]for j in range(51)]
Y_2dC =[0 for i in range(51)]
X_2dD = [[0 for i in range(8)]for j in range(32)]
Y_2dD =[0 for i in range(32)]
for i in range(1,120):
    if df_list[i][4]=='1':
        X_2dA[tA][0]=np.array(df_list[i][20])
        X_2dA[tA][1]=np.array(df_list[i][22])
        X_2dA[tA][2]=np.array(df_list[i][24])
        X_2dA[tA][3]=np.array(df_list[i][26])
        X_2dA[tA][4]=np.array(df_list[i][28])
        X_2dA[tA][5]=np.array(df_list[i][29])
        X_2dA[tA][6]=np.array(df_list[i][30])
        X_2dA[tA][7]=np.array(df_list[i][19])
        Y_2dA[tA]=np.array(df_list[i][4])
        tA=tA+1
for i in range(1,120):
    if df_list[i][4]=='2':
        X_2dB[tB][0]=np.array(df_list[i][20])
        X_2dB[tB][1]=np.array(df_list[i][22])
        X_2dB[tB][2]=np.array(df_list[i][24])
        X_2dB[tB][3]=np.array(df_list[i][26])
        X_2dB[tB][4]=np.array(df_list[i][28])
        X_2dB[tB][5]=np.array(df_list[i][29])
        X_2dB[tB][6]=np.array(df_list[i][30])
        X_2dB[tB][7]=np.array(df_list[i][19])
        Y_2dB[tB]=np.array(df_list[i][4])
        tB=tB+1
for i in range(1,120):
    if df_list[i][4]=='3':
        X_2dC[tC][0]=np.array(df_list[i][20])
        X_2dC[tC][1]=np.array(df_list[i][22])
        X_2dC[tC][2]=np.array(df_list[i][24])
        X_2dC[tC][3]=np.array(df_list[i][26])
        X_2dC[tC][4]=np.array(df_list[i][28])
        X_2dC[tC][5]=np.array(df_list[i][29])
        X_2dC[tC][6]=np.array(df_list[i][30])
        X_2dC[tC][7]=np.array(df_list[i][19])
        Y_2dC[tC]=np.array(df_list[i][4])
        tC=tC+1
for i in range(1,120):
    if df_list[i][4]=='4':
        X_2dD[tD][0]=np.array(df_list[i][20])
        X_2dD[tD][1]=np.array(df_list[i][22])
        X_2dD[tD][2]=np.array(df_list[i][24])
        X_2dD[tD][3]=np.array(df_list[i][26])
        X_2dD[tD][4]=np.array(df_list[i][28])
        X_2dD[tD][5]=np.array(df_list[i][29])
        X_2dD[tD][6]=np.array(df_list[i][30])
        X_2dD[tD][7]=np.array(df_list[i][19])
        Y_2dD[tD]=np.array(df_list[i][4])
        tD=tD+1
for i in range(1,51):
    if df_listA[i][4]=='1':
        X_2dA[tA][0]=np.array(df_listA[i][20])
        X_2dA[tA][1]=np.array(df_listA[i][22])
        X_2dA[tA][2]=np.array(df_listA[i][24])
        X_2dA[tA][3]=np.array(df_listA[i][26])
        X_2dA[tA][4]=np.array(df_listA[i][28])
        X_2dA[tA][5]=np.array(df_listA[i][29])
        X_2dA[tA][6]=np.array(df_listA[i][30])
        X_2dA[tA][7]=np.array(df_listA[i][19])
        Y_2dA[tA]=np.array(df_listA[i][4])
        tA=tA+1
for i in range(1,51):
    if df_listA[i][4]=='2':
        X_2dB[tB][0]=np.array(df_listA[i][20])
        X_2dB[tB][1]=np.array(df_listA[i][22])
        X_2dB[tB][2]=np.array(df_listA[i][24])
        X_2dB[tB][3]=np.array(df_listA[i][26])
        X_2dB[tB][4]=np.array(df_listA[i][28])
        X_2dB[tB][5]=np.array(df_listA[i][29])
        X_2dB[tB][6]=np.array(df_listA[i][30])
        X_2dB[tB][7]=np.array(df_listA[i][19])
        Y_2dB[tB]=np.array(df_listA[i][4])
        tB=tB+1
for i in range(1,51):
    if df_listA[i][4]=='3':
        X_2dC[tC][0]=np.array(df_listA[i][20])
        X_2dC[tC][1]=np.array(df_listA[i][22])
        X_2dC[tC][2]=np.array(df_listA[i][24])
        X_2dC[tC][3]=np.array(df_listA[i][26])
        X_2dC[tC][4]=np.array(df_listA[i][28])
        X_2dC[tC][5]=np.array(df_listA[i][29])
        X_2dC[tC][6]=np.array(df_listA[i][30])
        X_2dC[tC][7]=np.array(df_listA[i][19])
        Y_2dC[tC]=np.array(df_listA[i][4])
        tC=tC+1
for i in range(1,51):
    if df_listA[i][4]=='4':
        X_2dD[tD][0]=np.array(df_listA[i][20])
        X_2dD[tD][1]=np.array(df_listA[i][22])
        X_2dD[tD][2]=np.array(df_listA[i][24])
        X_2dD[tD][3]=np.array(df_listA[i][26])
        X_2dD[tD][4]=np.array(df_listA[i][28])
        X_2dD[tD][5]=np.array(df_listA[i][29])
        X_2dD[tD][6]=np.array(df_listA[i][30])
        X_2dD[tD][7]=np.array(df_listA[i][19])
        Y_2dD[tD]=np.array(df_listA[i][4])
        tD=tD+1

# %%
from sklearn.impute import KNNImputer
import numpy as np

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=15)
X_2dA=imputer.fit_transform(X_2dA)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=25)
X_2dB=imputer.fit_transform(X_2dB)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=26)
X_2dC=imputer.fit_transform(X_2dC)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=18)
X_2dD=imputer.fit_transform(X_2dD)

# %%
#fMRI data
I=0
for i in range(120):
    if i==0 or i==3 or i==4 or i==6 or i==42 or i==84 or i==114:
        continue;
    if i<10:
        data[I]=scio.loadmat('D:\\MATLAB\\R2016b\\bin\\conn_project2-1A\\resultsROI_Subject00'+str(i)+'_Condition001.mat')
    elif i>=10 and i<=99:
        data[I]=scio.loadmat('D:\\MATLAB\\R2016b\\bin\\conn_project2-1A\\resultsROI_Subject0'+str(i)+'_Condition001.mat')
    else:
        data[I]=scio.loadmat('D:\\MATLAB\\R2016b\\bin\\conn_project2-1A\\resultsROI_Subject'+str(i)+'_Condition001.mat')
    I=I+1

# %%
I=113
for i in range(51):
    if (i==0 or i==31 or i==32):
        continue
    if i<10:
        data[I]=scio.loadmat('D:\\LINE2-1\\conn_project2-add\\resultsROI_Subject00'+str(i)+'_Condition001.mat')
    elif i>=10 and i<=99:
        data[I]=scio.loadmat('D:\\LINE2-1\\conn_project2-add\\resultsROI_Subject0'+str(i)+'_Condition001.mat')
    else:
        data[I]=scio.loadmat('D:\\LINE2-1\\conn_project2-add\\resultsROI_Subject'+str(i)+'_Condition001.mat')
    I=I+1

# %%
XXX_2d = [[0 for i in range(13858)]for j in range(161)]

# %%
X ={ }
for i in range(161):
    X[i]=data[i]['Z']

# %%
t=0
for i in range(161):
    t=0
    for k in range(0,164):
        for l in range(k+1,164):
            XXX_2d[i][t]=np.array(X[i][k,l])
            t=t+1
    for k in range(0,164):
        for l in range(164,167):
            XXX_2d[i][t]=np.array(X[i][k,l])
            t=t+1

# %%
Y_2d =[0 for i in range(161)]

# %%
It=0
for i in range(120):
    if i==0 or i==3 or i==4 or i==6 or i==42 or i==84 or i==114:
        continue
    Y_2d[It]=df_list[i][4]
    It=It+1
for i in range(51):
    if i==0 or i==31 or i==32:
        continue;
    Y_2d[It]=df_listA[i][4]
    It=It+1

# %%
XX=np.array(XXX_2d)
YY=np.array(Y_2d,dtype='float')

# %%
from sklearn.feature_selection import SelectKBest, f_regression,f_classif
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
tAA,tBB,tCC,tDD=0,0,0,0
X_2d = [[0 for i in range(8)]for j in range(161)]
Y_2d =[0 for i in range(161)]
t=0
for i in range(1,120):
    if np.array(df_list[i][4])=='0':
        continue;
    if np.array(df_list[i][4])=='1':
        X_2d[t]=np.array(X_2dA[tAA])
        Y_2d[t]=np.array(Y_2dA[tAA])
        tAA=tAA+1
        t=t+1
    if np.array(df_list[i][4])=='2':
        X_2d[t]=np.array(X_2dB[tBB])
        Y_2d[t]=np.array(Y_2dB[tBB])
        tBB=tBB+1
        t=t+1
    if np.array(df_list[i][4])=='3':
        X_2d[t]=np.array(X_2dC[tCC])
        Y_2d[t]=np.array(Y_2dC[tCC])
        tCC=tCC+1
        t=t+1
    if np.array(df_list[i][4])=='4':
        X_2d[t]=np.array(X_2dD[tDD])
        Y_2d[t]=np.array(Y_2dD[tDD])
        tDD=tDD+1
        t=t+1

# %%
for i in range(1,51):
    if np.array(df_listA[i][4])=='0':
        continue;
    if np.array(df_listA[i][4])=='1':
        X_2d[t]=np.array(X_2dA[tAA])
        Y_2d[t]=np.array(Y_2dA[tAA])
        tAA=tAA+1
        t=t+1
    if np.array(df_listA[i][4])=='2':
        X_2d[t]=np.array(X_2dB[tBB])
        Y_2d[t]=np.array(Y_2dB[tBB])
        tBB=tBB+1
        t=t+1
    if np.array(df_listA[i][4])=='3':
        X_2d[t]=np.array(X_2dC[tCC])
        Y_2d[t]=np.array(Y_2dC[tCC])
        tCC=tCC+1
        t=t+1
    if np.array(df_listA[i][4])=='4':
        X_2d[t]=np.array(X_2dD[tDD])
        Y_2d[t]=np.array(Y_2dD[tDD])
        tDD=tDD+1
        t=t+1

# %%
from sklearn import svm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from math import sqrt
 
import torch
import torch.nn as nn
 
class SelfAttention(nn.Module):
    def __init__(self, dim_q, dim_k, dim_v):
        super(SelfAttention, self).__init__()
        self.dim_q = dim_q
        self.dim_k = dim_k
        self.dim_v = dim_v
 
        self.linear_q = nn.Linear(dim_q, dim_k,bias=False)
        self.linear_k = nn.Linear(dim_q, dim_k,bias=False)
        self.linear_v = nn.Linear(dim_q, dim_v,bias=False)
        self._norm_fact = 1 / sqrt(dim_k)
 
    def forward(self, x):
        # x: batch, n, dim_q
 
        batch, dim_q = x.shape
        n = 1
        assert dim_q == self.dim_q
        q = self.linear_q(x)  # batch, n, dim_k
        k = self.linear_k(x)  # batch, n, dim_k
        v = self.linear_v(x)  # batch, n, dim_v
        dist = torch.mm(q, k.transpose(0,1)) * self._norm_fact  # batch, n, n
        dist = torch.softmax(dist, dim=-1)  # batch, n, n
        att = torch.mm(dist, v)
        return att

# %%
ACC=np.array([0 for i in range(1000)],dtype='float')

# %%
#Regression indicators
import pandas as pd
dfAGE = pd.read_csv("./R_loss.csv",encoding="UTF-8")
dfAGE_array = np.array(dfAGE)
dfAGE_list = dfAGE_array.tolist()

# %%
#Normalization is required
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from scipy.io import savemat

# %%
import torch
from torch import tensor
torch.set_default_tensor_type(torch.DoubleTensor)
ALL_best=0
Best_ACC=0
Best_RE=0
Best_F1=0
Best_FLAG=0
LOW_ACC=1.1
LOW_RE=1.1
LOW_F1=1.1
LOW_FLAG=0
AVG_ACC=0
DF=0;
DB=0;
DV=0;
DM=0;
op_now=0

dataXR={}
dataXE={}


   
ACCNOW=[0 for i in range(825)]
for iii in range(50,350,1):
    
    XR = np.array([[0 for i in range(iii+7)]for j in range(138)],dtype='float')
    XE = np.array([[0 for i in range(iii+7)]for j in range(23)],dtype='float')

#     XR_2d=np.array([0 for i in range(138)],dtype='float')
#     XE_2d=np.array([0 for i in range(23)],dtype='float')
    
    selector = SelectKBest(f_classif, k=iii)
    X_train =np.array([[0 for i in range(13858)] for j in range(138)],dtype='float')
    X_test =np.array([[0 for i in range(13858)] for j in range(23)],dtype='float')
    Y_train=np.array([0 for i in range(138)],dtype='int')
    Y_test=np.array([0 for i in range(23)],dtype='int')
    X_trainA =np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
    X_testA =np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
    Y_trainA=np.array([0 for i in range(138)],dtype='int')
    Y_testA=np.array([0 for i in range(23)],dtype='int')
    u,v=0,0;
    dataXR=scio.loadmat("./X_now_train"+str(iii)+"_P"+str(op_now)+".mat")
    dataXE=scio.loadmat(",/X_now_test"+str(iii)+"_P"+str(op_now)+".mat")
    for j in range(138):
        XR[j]=np.array(dataXR['data'][j])
    for j in range(23):
        XE[j]=np.array(dataXE['data'][j])
    XR_2d=np.array(XR)
    XE_2d=np.array(XE)
    print(XR_2d.shape,XR_2d[0])
    print(XE_2d.shape,XE_2d[0])
    for j in range(161):
        if (j%7==op_now):
            X_test[u]=XX[j]
            Y_test[u]=YY[j]
            u=u+1;
        else:
            X_train[v]=XX[j]
            Y_train[v]=YY[j]
            v=v+1;
    for kkk in range(60):
        X_newR = selector.fit_transform(X_train,Y_train)
        X_newE = selector.transform(X_test)
        model=SelfAttention(161,iii+13,iii+13)
        X_newRA = np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
        X_newEA = np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
        Feature=np.zeros((iii+13,161))
        u,v=0,0;
        for i in range(161):
            if (i%7==op_now):
                for j in range(iii):
                    X_newEA[u][j]=np.array(X_newE[u][j]+XE_2d[u][iii]*0.1,dtype=float)
                t=iii
                for j in range(7):
                    X_newEA[u][t]=np.array(X_2d[i][j]+XE_2d[u][t]*0.1,dtype=float)
                    t=t+1
                for j in range(6):
                    X_newEA[u][t]=np.array(dfAGE_list[i][j],dtype=float)
                    t=t+1
                u=u+1
            else:
                for j in range(iii):
                    X_newRA[v][j]=np.array(X_newR[v][j]++XR_2d[v][iii]*0.1,dtype=float)
                t=iii
                for j in range(7):
                    X_newRA[v][t]=np.array(X_2d[i][j]+XR_2d[v][t]*0.1,dtype=float)
                    t=t+1
                for j in range(6):
                    X_newRA[v][t]=np.array(dfAGE_list[i][j],dtype=float)
                    t=t+1
                v=v+1
        for i in range(iii+13):
            u,v=0,0;
            for j in range(161):
                if (j%7==op_now):
                    Feature[i][j]=np.array(X_newEA[u][i])
                    u=u+1
                else:
                    Feature[i][j]=np.array(X_newRA[v][i])
                    v=v+1
        Feature_tensor = torch.from_numpy(Feature)
#    print('Feature_shape:',Feature_tensor.shape)
        YQ1=model(Feature_tensor)
#         tagAA=[0 for i in range(iii+13)]
#         for i in range(iii+13):
#             tagAA[i]=sum(YQ1[i]).detach().numpy()
        tagAA=torch.sum(YQ1, dim=1)
        u,v=0,0;
        for i in range(161):
            if (i%7==op_now):
                for j in range(iii+13):
                    X_testA[u][j]=X_newEA[u][j]*tagAA[j].detach().numpy()
                u=u+1
            else:
                for j in range(iii+13):
                    X_trainA[v][j]=X_newRA[v][j]*tagAA[j].detach().numpy()
                v=v+1
        ACC=0;
        cnt=0;
        clf_linear = svm.SVC(kernel='linear',C=0.095)
        clf_linear.fit(X_trainA,Y_train)
        score_linear_test = clf_linear.score(X_testA,Y_test)
        score_linear_train = clf_linear.score(X_trainA,Y_train)
        predict_test = clf_linear.predict(X_testA)
#         print("SVM Test  Accuracy : %.4g" % (score_linear_test))
#         print("SVM Train  Accuracy : %.4g" % (score_linear_train))
        ACC=ACC+score_linear_test;
        cnt=cnt+1;
        ACC=ACC/cnt
        AVG_ACC=AVG_ACC+ACC
        if ACC>Best_ACC:
            Best_FLAG=iii
            Best_ACC=ACC
        if ACC<LOW_ACC:
            LOW_FLAG=iii
            LOW_ACC=ACC
        print(iii,kkk,ACC)
        if (ACCNOW[iii]<ACC):
            ACCNOW[iii]=ACC
            PATH = "./ARZE"+str(iii)+"_P"+str(op_now)+".pth"
            torch.save(model.state_dict(), PATH)
            savemat('X_now_train'+str(iii)+'_P'+str(op_now)+'.mat', {'data': X_trainA})
            savemat('X_now_test'+str(iii)+'_P'+str(op_now)+'.mat', {'data': X_testA})
    print(iii,ACCNOW[iii])
print("BEST:")
print(Best_FLAG,Best_ACC)
print(LOW_FLAG,LOW_ACC)
print("ACC")

print("  ")
print("  ")
print("   ")

for i in range(50,350):
    print(ACCNOW[i])

# %%
import torch
from torch import tensor
torch.set_default_tensor_type(torch.DoubleTensor)

op_now=0

dataXR={}
dataXE={}

iii=202

XR = np.array([[0 for i in range(iii+7)]for j in range(138)],dtype='float')
XE = np.array([[0 for i in range(iii+7)]for j in range(23)],dtype='float')

#     XR_2d=np.array([0 for i in range(138)],dtype='float')
#     XE_2d=np.array([0 for i in range(23)],dtype='float')
    
selector = SelectKBest(f_classif, k=iii)
X_train =np.array([[0 for i in range(13858)] for j in range(138)],dtype='float')
X_test =np.array([[0 for i in range(13858)] for j in range(23)],dtype='float')
Y_train=np.array([0 for i in range(138)],dtype='int')
Y_test=np.array([0 for i in range(23)],dtype='int')
X_trainA =np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
X_testA =np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
Y_trainA=np.array([0 for i in range(138)],dtype='int')
Y_testA=np.array([0 for i in range(23)],dtype='int')
u,v=0,0;
dataXR=scio.loadmat("./X_now_train"+str(iii)+"_P"+str(op_now)+".mat")
dataXE=scio.loadmat("./X_now_test"+str(iii)+"_P"+str(op_now)+".mat")
for j in range(138):
    XR[j]=np.array(dataXR['data'][j])
for j in range(23):
    XE[j]=np.array(dataXE['data'][j])
XR_2d=np.array(XR)
XE_2d=np.array(XE)
# print(XR_2d.shape,XR_2d[0])
# print(XE_2d.shape,XE_2d[0])
for j in range(161):
    if (j%7==op_now):
        X_test[u]=XX[j]
        Y_test[u]=YY[j]
        u=u+1;
    else:
        X_train[v]=XX[j]
        Y_train[v]=YY[j]
        v=v+1;

X_newR = selector.fit_transform(X_train,Y_train)
X_newE = selector.transform(X_test)
model=SelfAttention(161,iii+13,iii+13)
save_model = torch.load("./ARZE"+str(iii)+"_P"+str(op_now)+".pth")
model_dict =  model.state_dict()
state_dict = {k:v for k,v in save_model.items() if k in model_dict.keys()}
model_dict.update(state_dict)
model.load_state_dict(model_dict)

X_newRA = np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
X_newEA = np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
Feature=np.zeros((iii+13,161))
u,v=0,0;
for i in range(161):
    if (i%7==op_now):
        for j in range(iii):
            X_newEA[u][j]=np.array(X_newE[u][j]+XE_2d[u][iii]*0.1,dtype=float)
        t=iii
        for j in range(7):
            X_newEA[u][t]=np.array(X_2d[i][j]+XE_2d[u][t]*0.1,dtype=float)
            t=t+1
        for j in range(6):
            X_newEA[u][t]=np.array(dfAGE_list[i][j],dtype=float)
            t=t+1
        u=u+1
    else:
        for j in range(iii):
            X_newRA[v][j]=np.array(X_newR[v][j]++XR_2d[v][iii]*0.1,dtype=float)
        t=iii
        for j in range(7):
            X_newRA[v][t]=np.array(X_2d[i][j]+XR_2d[v][t]*0.1,dtype=float)
            t=t+1
        for j in range(6):
            X_newRA[v][t]=np.array(dfAGE_list[i][j],dtype=float)
            t=t+1
        v=v+1
for i in range(iii+13):
    u,v=0,0;
    for j in range(161):
        if (j%7==op_now):
            Feature[i][j]=np.array(X_newEA[u][i])
            u=u+1
        else:
            Feature[i][j]=np.array(X_newRA[v][i])
            v=v+1
Feature_tensor = torch.from_numpy(Feature)
YQ1=model(Feature_tensor)
tagAA=torch.sum(YQ1, dim=1)
u,v=0,0;
for i in range(161):
    if (i%7==op_now):
        for j in range(iii+13):
            X_testA[u][j]=X_newEA[u][j]*tagAA[j].detach().numpy()
        u=u+1
    else:
        for j in range(iii+13):
            X_trainA[v][j]=X_newRA[v][j]*tagAA[j].detach().numpy()
        v=v+1
ACC=0;
cnt=0;
clf_linear = svm.SVC(kernel='linear',C=0.095)
clf_linear.fit(X_trainA,Y_train)
score_linear_test = clf_linear.score(X_testA,Y_test)
score_linear_train = clf_linear.score(X_trainA,Y_train)
predict_test = clf_linear.predict(X_testA)
#         print("SVM Test  Accuracy : %.4g" % (score_linear_test))
#         print("SVM Train  Accuracy : %.4g" % (score_linear_train))
ACC=ACC+score_linear_test;
cnt=cnt+1;
ACC=ACC/cnt
print(iii,ACC)
# Out:
# C:\Users\hppc\AppData\Local\Temp\ipykernel_36796\622158024.py:52: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   save_model = torch.load("./ARZE"+str(iii)+"_P"+str(op_now)+".pth")
# 202 0.782608695652174

# %%
X_hot= np.array([[0 for i in range(4)] for j in range(161)],dtype='float')

# %%
for i in range(7):
    for j in range(23):
        for k in range(4):
            X_hot[j*7+i][k]=SOFTMAX[i][j][k]

# %%
WA=0
WAP=0
for i in range(161):
    print(i,X_hot[i],np.argmax(X_hot[i]),YY[i]-1,PRED[i]-1)
    if (np.argmax(X_hot[i])!=YY[i]-1):
        WA=WA+1
    if (PRED[i]!=YY[i]):
        WAP=WAP+1
    if (np.argmax(X_hot[i])!=PRED[i]-1):
        print(i,"ERROR!!!")
print(WA)
print(WAP)

# %%
Y_hot = np.array([[0 for i in range(4)] for j in range(161)])
for i in range(161):
    S = int(YY[i] - 1)
    Y_hot[i][S] = 1
Y_loss = [0 for i in range(161)]
for i in range(161):
    Y_loss[i] = categorical_cross_entropy(Y_hot[i], X_hot[i])
    print(Y_loss[i])
lists = [Y_loss]
print(Y_loss)
print(lists)

# %%
def categorical_cross_entropy(y_true, y_pred):
    epsilon = 1e-7
    loss = -np.sum(y_true * np.log(y_pred + epsilon))
    return loss
