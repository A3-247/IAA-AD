# %%
#load data
import scipy.io as scio
data={ }

# %%
import numpy as np 
from numpy import array

# %%
import pandas as pd
df = pd.read_csv("./ADNI_MUL_T1_6_24_2024.csv",encoding="ANSI")
df_array = np.array(df)
df_list = df_array.tolist()

# %%
tA,tB,tC,tD=0,0,0,0
X_2dA = [[0 for i in range(8)]for j in range(29)]
Y_2dA =[0 for i in range(29)]
X_2dB = [[0 for i in range(8)]for j in range(49)]
Y_2dB =[0 for i in range(49)]
X_2dC = [[0 for i in range(8)]for j in range(51)]
Y_2dC =[0 for i in range(51)]
X_2dD = [[0 for i in range(8)]for j in range(32)]
Y_2dD =[0 for i in range(32)]
for i in range(1,161):
    if df_list[i][4]=='1':
        X_2dA[tA][0]=np.array(df_list[i][20])
        X_2dA[tA][1]=np.array(df_list[i][22])
        X_2dA[tA][2]=np.array(df_list[i][24])
        X_2dA[tA][3]=np.array(df_list[i][26])
        X_2dA[tA][4]=np.array(df_list[i][28])
        X_2dA[tA][5]=np.array(df_list[i][29])
        X_2dA[tA][6]=np.array(df_list[i][30])
        X_2dA[tA][7]=np.array(df_list[i][19])
        Y_2dA[tA]=np.array(df_list[i][4])
        tA=tA+1
for i in range(1,161):
    if df_list[i][4]=='2':
        X_2dB[tB][0]=np.array(df_list[i][20])
        X_2dB[tB][1]=np.array(df_list[i][22])
        X_2dB[tB][2]=np.array(df_list[i][24])
        X_2dB[tB][3]=np.array(df_list[i][26])
        X_2dB[tB][4]=np.array(df_list[i][28])
        X_2dB[tB][5]=np.array(df_list[i][29])
        X_2dB[tB][6]=np.array(df_list[i][30])
        X_2dB[tB][7]=np.array(df_list[i][19])
        Y_2dB[tB]=np.array(df_list[i][4])
        tB=tB+1
for i in range(1,161):
    if df_list[i][4]=='3':
        X_2dC[tC][0]=np.array(df_list[i][20])
        X_2dC[tC][1]=np.array(df_list[i][22])
        X_2dC[tC][2]=np.array(df_list[i][24])
        X_2dC[tC][3]=np.array(df_list[i][26])
        X_2dC[tC][4]=np.array(df_list[i][28])
        X_2dC[tC][5]=np.array(df_list[i][29])
        X_2dC[tC][6]=np.array(df_list[i][30])
        X_2dC[tC][7]=np.array(df_list[i][19])
        Y_2dC[tC]=np.array(df_list[i][4])
        tC=tC+1
for i in range(1,161):
    if df_list[i][4]=='4':
        X_2dD[tD][0]=np.array(df_list[i][20])
        X_2dD[tD][1]=np.array(df_list[i][22])
        X_2dD[tD][2]=np.array(df_list[i][24])
        X_2dD[tD][3]=np.array(df_list[i][26])
        X_2dD[tD][4]=np.array(df_list[i][28])
        X_2dD[tD][5]=np.array(df_list[i][29])
        X_2dD[tD][6]=np.array(df_list[i][30])
        X_2dD[tD][7]=np.array(df_list[i][19])
        Y_2dD[tD]=np.array(df_list[i][4])
        tD=tD+1

# %%
from sklearn.impute import KNNImputer
import numpy as np

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=15)
X_2dA=imputer.fit_transform(X_2dA)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=25)
X_2dB=imputer.fit_transform(X_2dB)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=26)
X_2dC=imputer.fit_transform(X_2dC)

# %%
#Distance Calculation
from sklearn.metrics.pairwise import nan_euclidean_distances
imputer = KNNImputer(n_neighbors=18)
X_2dD=imputer.fit_transform(X_2dD)

# %%
#AfMRI
I=0
for i in range(120):
    if i<10:
        data[I]=scio.loadmat('./resultsROI_Subject00'+str(i)+'_Condition001.mat')
    elif i>=10 and i<=99:
        data[I]=scio.loadmat('./resultsROI_Subject0'+str(i)+'_Condition001.mat')
    else:
        data[I]=scio.loadmat('./resultsROI_Subject'+str(i)+'_Condition001.mat')
    I=I+1

# %%
X ={ }
for i in range(161):
    X[i]=data[i]['Z']

# %%
XXX_2d = [[0 for i in range(13858)]for j in range(161)]

t=0
for i in range(161):
    t=0
    for k in range(0,164):
        for l in range(k+1,164):
            XXX_2d[i][t]=np.array(X[i][k,l])
            t=t+1
    for k in range(0,164):
        for l in range(164,167):
            XXX_2d[i][t]=np.array(X[i][k,l])
            t=t+1

# %%
Y2 =[0 for i in range(161)]
It=0
for i in range(161):
    Y2[It]=df_list[i][31]
    It=It+1

# %%
XX=np.array(XXX_2d)
YY=np.array(Y2,dtype='float')

# %%
from sklearn.feature_selection import SelectKBest, f_regression,f_classif
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
tAA,tBB,tCC,tDD=0,0,0,0
X_2d = [[0 for i in range(8)]for j in range(161)]
Y_2d =[0 for i in range(161)]
t=0
for i in range(1,120):
    if np.array(df_list[i][4])=='0':
        continue;
    if np.array(df_list[i][4])=='1':
        X_2d[t]=np.array(X_2dA[tAA])
        Y_2d[t]=np.array(Y_2dA[tAA])
        tAA=tAA+1
        t=t+1
    if np.array(df_list[i][4])=='2':
        X_2d[t]=np.array(X_2dB[tBB])
        Y_2d[t]=np.array(Y_2dB[tBB])
        tBB=tBB+1
        t=t+1
    if np.array(df_list[i][4])=='3':
        X_2d[t]=np.array(X_2dC[tCC])
        Y_2d[t]=np.array(Y_2dC[tCC])
        tCC=tCC+1
        t=t+1
    if np.array(df_list[i][4])=='4':
        X_2d[t]=np.array(X_2dD[tDD])
        Y_2d[t]=np.array(Y_2dD[tDD])
        tDD=tDD+1
        t=t+1

# %%
for i in range(1,51):
    if np.array(df_listA[i][4])=='0':
        continue;
    if np.array(df_listA[i][4])=='1':
        X_2d[t]=np.array(X_2dA[tAA])
        Y_2d[t]=np.array(Y_2dA[tAA])
        tAA=tAA+1
        t=t+1
    if np.array(df_listA[i][4])=='2':
        X_2d[t]=np.array(X_2dB[tBB])
        Y_2d[t]=np.array(Y_2dB[tBB])
        tBB=tBB+1
        t=t+1
    if np.array(df_listA[i][4])=='3':
        X_2d[t]=np.array(X_2dC[tCC])
        Y_2d[t]=np.array(Y_2dC[tCC])
        tCC=tCC+1
        t=t+1
    if np.array(df_listA[i][4])=='4':
        X_2d[t]=np.array(X_2dD[tDD])
        Y_2d[t]=np.array(Y_2dD[tDD])
        tDD=tDD+1
        t=t+1

# %%
from sklearn import svm
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from math import sqrt
 
import torch
import torch.nn as nn
 
class SelfAttention(nn.Module):
    def __init__(self, dim_q, dim_k, dim_v):
        super(SelfAttention, self).__init__()
        self.dim_q = dim_q
        self.dim_k = dim_k
        self.dim_v = dim_v
 
        self.linear_q = nn.Linear(dim_q, dim_k,bias=False)
        self.linear_k = nn.Linear(dim_q, dim_k,bias=False)
        self.linear_v = nn.Linear(dim_q, dim_v,bias=False)
        self._norm_fact = 1 / sqrt(dim_k)
 
    def forward(self, x):
        # x: batch, n, dim_q
 
        batch, dim_q = x.shape
        #print('batch=',batch,'dim_q',dim_q)
        n = 1
        assert dim_q == self.dim_q
        q = self.linear_q(x)  # batch, n, dim_k
        k = self.linear_k(x)  # batch, n, dim_k
        v = self.linear_v(x)  # batch, n, dim_v
       # print(q.shape)
       # print(k.shape)
        dist = torch.mm(q, k.transpose(0,1)) * self._norm_fact  # batch, n, n
        dist = torch.softmax(dist, dim=-1)  # batch, n, n
        att = torch.mm(dist, v)
        return att

# %%
import pandas as pd
dfAGE = pd.read_csv("./C_loss.csv",encoding="UTF-8")
dfAGE_array = np.array(dfAGE)
dfAGE_list = dfAGE_array.tolist()

# %%
from scipy.io import savemat

# %%
#import pymp
torch.set_default_tensor_type(torch.DoubleTensor)
Best_rmse=10000
Best_RE=0
Best_F1=0
Best_FLAG=0
LOW_ACC=1.1
LOW_RE=1.1
LOW_F1=1.1
LOW_FLAG=0
AVG_ACC=0
DF=0;
DB=0;
DV=0;
DM=0;
op_now=0
mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
RMSE=np.array([10000 for i in range(1024)],dtype='float')
MSEEE=np.array([10000 for i in range(1024)],dtype='float')
MAEEE=np.array([10000 for i in range(1024)],dtype='float')
R222=np.array([10000 for i in range(1024)],dtype='float')
for iii in range(50,750,1):
    selector = SelectKBest(f_classif, k=iii)
    X_train =np.array([[0 for i in range(13858)] for j in range(138)],dtype='float')
    X_test =np.array([[0 for i in range(13858)] for j in range(23)],dtype='float')
    Y_train=np.array([0 for i in range(138)],dtype='float')
    Y_test=np.array([0 for i in range(23)],dtype='float')
    X_trainA =np.array([[0 for i in range(iii+7)] for j in range(138)],dtype='float')
    X_testA =np.array([[0 for i in range(iii+7)] for j in range(23)],dtype='float')
    Y_trainA=np.array([0 for i in range(138)],dtype='float')
    Y_testA=np.array([0 for i in range(23)],dtype='float')
    u,v=0,0;
    mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
    YSE_test = np.array([0 for i in range (23)],dtype=int)
    YSE_train = np.array([0 for i in range (138)],dtype=int)
    for j in range(161):
        if (j%7==op_now):
            X_test[u]=XX[j]
            Y_test[u]=YY[j]
            YSE_test[u]=Y_2d[j]
            u=u+1;
        else:
            X_train[v]=XX[j]
            Y_train[v]=YY[j]
            YSE_train[v]=Y_2d[j]
            v=v+1;
    for kkk in range(20):
        X_newR = selector.fit_transform(X_train,YSE_train)
        X_newE = selector.transform(X_test)
        model=SelfAttention(161,iii+13,iii+13)
        mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
        X_newRA = np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
        X_newEA = np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
        Feature=np.zeros((iii+7,161))
        u,v=0,0;
        for i in range(161):
            if (i%7==op_now):
                for j in range(iii):
                    X_newEA[u][j]=X_newE[u][j]
                t=iii
                for j in range(7):
                    X_newEA[u][t]=np.array(X_2d[i][j],dtype=float)
                    t=t+1
                u=u+1;
                for j in range(6):
                    X_newEA[u][t]=np.array(dfAGE_list[i][j],dtype=float)
                    t=t+1
            else:
                for j in range(iii):
                    X_newRA[v][j]=X_newR[v][j]
                t=iii
                for j in range(7):
                    X_newRA[v][t]=np.array(X_2d[i][j],dtype=float)
                    t=t+1
                for j in range(6):
                    X_newRA[v][t]=np.array(dfAGE_list[i][j],dtype=float)
                    t=t+1
                v=v+1
        for i in range(iii+13):
            u,v=0,0;
            for j in range(161):
                if (j%7==op_now):
                    Feature[i][j]=np.array(X_newEA[u][i])
                    u=u+1
                else:
                    Feature[i][j]=np.array(X_newRA[v][i])
                    v=v+1
        Feature_tensor = torch.from_numpy(Feature)
#    print('Feature_shape:',Feature_tensor.shape)
        YQ1=model(Feature_tensor)
#         tagAA=[0 for i in range(iii+13)]
#         for i in range(iii+13):
#             tagAA[i]=sum(YQ1[i]).detach().numpy()
        tagAA=torch.sum(YQ1, dim=1)
        u,v=0,0;
        for i in range(161):
            if (i%7==op_now):
                for j in range(iii+13):
                    X_testA[u][j]=X_newEA[u][j]*tagAA[j].detach().numpy()
                u=u+1
            else:
                for j in range(iii+13):
                    X_trainA[v][j]=X_newRA[v][j]*tagAA[j].detach().numpy()
                v=v+1
        ACC=0;
        cnt=0;
        clf = svm.SVR(kernel='linear',C=0.095)
        predict_test = clf.fit (X_trainA, Y_train.ravel())
        score_test = clf.score(X_testA,Y_test)
        score_train = clf.score(X_trainA,Y_train)
        predict_test = clf.predict(X_testA)
#         print("SVM Test Score : %.4g" % (score_test))
#         print("SVM Train Score : %.4g" % (score_train))
        mse = mse+mean_squared_error(Y_test, predict_test)
        mae = mae+mean_absolute_error(Y_test, predict_test)
        r2 = r2+r2_score(Y_test, predict_test)
        cnt=cnt+1
        mse=mse/cnt
        rmse = mse ** 0.5
        mae=mae/cnt
        r2=r2/cnt
        print("epoch:",iii,"kkk",kkk,f'MSE: {mse}',f'RMSE: {rmse}',f'MAE: {mae}',f'R^2: {R222[iii]}')
#         print(iii,kkk,ACC)
        if (rmse<RMSE[iii]):
            MSEEE[iii]=mse
            RMSE[iii]=rmse
            MAEEE[iii]=mae
            R222[iii]=r2
            PATH = "./AGE"+str(iii)+"_P"+str(op_now)+".pth"
            torch.save(model.state_dict(), PATH)
            savemat('X_now_train'+str(iii)+'_P'+str(op_now)+'.mat', {'data': X_newRA})
            savemat('X_now_test'+str(iii)+'_P'+str(op_now)+'.mat', {'data': X_newEA})
    print("epoch:",iii,f'MSE: {MSEEE[iii]}',f'RMSE: {RMSE[iii]}',f'MAE: {MAEEE[iii]}',f'R^2: {R222[iii]}')
    if (RMSE[iii]<Best_rmse):
        Best_rmse=RMSE[iii]
print(Best_rmse)

# %%
#import pymp
torch.set_default_tensor_type(torch.DoubleTensor)
Best_rmse=10000
Best_RE=0
Best_F1=0
Best_FLAG=0
LOW_ACC=1.1
LOW_RE=1.1
LOW_F1=1.1
LOW_FLAG=0
AVG_ACC=0
DF=0;
DB=0;
DV=0;
DM=0;
op_now=0
iii=92
mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
RMSE=np.array([10000 for i in range(1024)],dtype='float')
MSEEE=np.array([10000 for i in range(1024)],dtype='float')
MAEEE=np.array([10000 for i in range(1024)],dtype='float')
R222=np.array([10000 for i in range(1024)],dtype='float')

selector = SelectKBest(f_classif, k=iii)
X_train =np.array([[0 for i in range(13858)] for j in range(138)],dtype='float')
X_test =np.array([[0 for i in range(13858)] for j in range(23)],dtype='float')
Y_train=np.array([0 for i in range(138)],dtype='float')
Y_test=np.array([0 for i in range(23)],dtype='float')
X_trainA =np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
X_testA =np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
Y_trainA=np.array([0 for i in range(138)],dtype='float')
Y_testA=np.array([0 for i in range(23)],dtype='float')
u,v=0,0;
mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
YSE_test = np.array([0 for i in range (23)],dtype=int)
YSE_train = np.array([0 for i in range (138)],dtype=int)
for j in range(161):
    if (j%7==op_now):
        X_test[u]=XX[j]
        Y_test[u]=YY[j]
        YSE_test[u]=Y_2d[j]
        u=u+1;
    else:
        X_train[v]=XX[j]
        Y_train[v]=YY[j]
        YSE_train[v]=Y_2d[j]
        v=v+1;

X_newR = selector.fit_transform(X_train,YSE_train)
X_newE = selector.transform(X_test)
model=SelfAttention(161,iii+13,iii+13)
save_model = torch.load("./AGE"+str(iii)+"_P"+str(op_now)+".pth")
model_dict =  model.state_dict()
state_dict = {k:v for k,v in save_model.items() if k in model_dict.keys()}
print(state_dict.keys())
model_dict.update(state_dict)
model.load_state_dict(model_dict)
mse,mae,r2=np.array(0,dtype='float'),np.array(0,dtype='float'),np.array(0,dtype='float')
X_newRA = np.array([[0 for i in range(iii+13)] for j in range(138)],dtype='float')
X_newEA = np.array([[0 for i in range(iii+13)] for j in range(23)],dtype='float')
Feature=np.zeros((iii+7,161))
u,v=0,0;
for i in range(161):
    if (i%7==op_now):
        for j in range(iii):
            X_newEA[u][j]=X_newE[u][j]
        t=iii
        for j in range(7):
            X_newEA[u][t]=np.array(X_2d[i][j],dtype=float)
            t=t+1
        for j in range(6):
            X_newEA[u][t]=np.array(dfAGE_list[i][j],dtype=float)
            t=t+1
        u=u+1;
    else:
        for j in range(iii):
            X_newRA[v][j]=X_newR[v][j]
        t=iii
        for j in range(7):
            X_newRA[v][t]=np.array(X_2d[i][j],dtype=float)
            t=t+1
        for j in range(6):
            X_newRA[u][t]=np.array(dfAGE_list[i][j],dtype=float)
            t=t+1
        v=v+1
for i in range(iii+7):
    u,v=0,0;
    for j in range(161):
        if (j%7==op_now):
            Feature[i][j]=np.array(X_newEA[u][i])
            u=u+1
        else:
            Feature[i][j]=np.array(X_newRA[v][i])
            v=v+1
Feature_tensor = torch.from_numpy(Feature)
YQ1=model(Feature_tensor)
tagAA=torch.sum(YQ1, dim=1)
u,v=0,0;
for i in range(161):
    if (i%7==op_now):
        for j in range(iii+13):
            X_testA[u][j]=X_newEA[u][j]*tagAA[j].detach().numpy()
        u=u+1
    else:
        for j in range(iii+13):
            X_trainA[v][j]=X_newRA[v][j]*tagAA[j].detach().numpy()
        v=v+1
ACC=0;
cnt=0;
clf = svm.SVR(kernel='linear',C=0.095)
predict_test = clf.fit (X_trainA, Y_train.ravel())
score_test = clf.score(X_testA,Y_test)
score_train = clf.score(X_trainA,Y_train)
predict_test = clf.predict(X_testA)
mse = mse+mean_squared_error(Y_test, predict_test)
mae = mae+mean_absolute_error(Y_test, predict_test)
r2 = r2+r2_score(Y_test, predict_test)
cnt=cnt+1
mse=mse/cnt
rmse = mse ** 0.5
mae=mae/cnt
r2=r2/cnt
if (rmse<RMSE[iii]):
    MSEEE[iii]=mse
    RMSE[iii]=rmse
    MAEEE[iii]=mae
    R222[iii]=r2
print("epoch:",iii,f'MSE: {MSEEE[iii]}',f'RMSE: {RMSE[iii]}',f'MAE: {MAEEE[iii]}',f'R^2: {R222[iii]}')
if (RMSE[iii]<Best_rmse):
    Best_rmse=RMSE[iii]
print(Best_rmse)

# %%
Y_sub=np.array([0 for i in range(23)],dtype='float')
for i in range(23):
    Y_sub[i]=Y_test[i]-predict_test[i]
print(Y_sub)
